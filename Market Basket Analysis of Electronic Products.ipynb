# %%
import pandas as pd
import numpy as np

# %%
import os
import glob

folder_path = r'C:\Users\stuti\Downloads\Sales-Analysis-Dataset'
files = glob.glob(os.path.join(folder_path, '*'))  # This will match all files in the folder

for file_path in files:
    print(os.path.basename(file_path))
# Out:
# Combined_Sales_2019.csv
# Sales_April_2019.csv
# Sales_August_2019.csv
# Sales_December_2019.csv
# Sales_February_2019.csv
# Sales_January_2019.csv
# Sales_July_2019.csv
# Sales_June_2019.csv
# Sales_March_2019.csv
# Sales_May_2019.csv
# Sales_November_2019.csv
# Sales_October_2019.csv
# Sales_September_2019.csv

# %%
file_path1 = r'C:\Users\stuti\Downloads\Sales-Analysis-Dataset\Sales_April_2019.csv'  
file_path2 = r'C:\Users\stuti\Downloads\Sales-Analysis-Dataset\Sales_August_2019.csv'    
file_path3 = r'C:\Users\stuti\Downloads\Sales-Analysis-Dataset\Sales_December_2019.csv'   
file_path4 = r'C:\Users\stuti\Downloads\Sales-Analysis-Dataset\Sales_February_2019.csv'  
file_path5 = r'C:\Users\stuti\Downloads\Sales-Analysis-Dataset\Sales_January_2019.csv'    
file_path6 = r'C:\Users\stuti\Downloads\Sales-Analysis-Dataset\Sales_July_2019.csv'   
file_path7 = r'C:\Users\stuti\Downloads\Sales-Analysis-Dataset\Sales_June_2019.csv'  
file_path8 = r'C:\Users\stuti\Downloads\Sales-Analysis-Dataset\Sales_March_2019.csv'   
file_path9 = r'C:\Users\stuti\Downloads\Sales-Analysis-Dataset\Sales_May_2019.csv'
file_path10 = r'C:\Users\stuti\Downloads\Sales-Analysis-Dataset\Sales_November_2019.csv'   
file_path11 = r'C:\Users\stuti\Downloads\Sales-Analysis-Dataset\Sales_October_2019.csv'  
file_path12 = r'C:\Users\stuti\Downloads\Sales-Analysis-Dataset\Sales_October_2019.csv'

# %%
df1 = pd.read_csv(file_path1)
df2 = pd.read_csv(file_path2)
df3 = pd.read_csv(file_path3)
df4 = pd.read_csv(file_path4)
df5 = pd.read_csv(file_path5)
df6 = pd.read_csv(file_path6)
df7 = pd.read_csv(file_path7)
df8 = pd.read_csv(file_path8)
df9 = pd.read_csv(file_path9)
df10 = pd.read_csv(file_path10)
df11 = pd.read_csv(file_path11)
df12 = pd.read_csv(file_path12)

combined_df = pd.concat([df1, df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12], ignore_index=True)

# %%
output_file = os.path.join(folder_path, 'Combined_Sales_2019.csv')
combined_df.to_csv(output_file, index=False)
print(f"Combined CSV saved as '{output_file}'")
# Out:
# Combined CSV saved as 'C:\Users\stuti\Downloads\Sales-Analysis-Dataset\Combined_Sales_2019.csv'

# %%
import pandas as pd
df= pd.read_csv(r'C:\Users\stuti\Downloads\Sales-Analysis-Dataset\Combined_Sales_2019.csv')

# %%
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 195538   278792       AA Batteries (4-pack)                1       3.84
# 195539   278793            Wired Headphones                1      11.99
# 195540   278794       AA Batteries (4-pack)                1       3.84
# 195541   278795                      iPhone                1        700
# 195542   278796            Wired Headphones                1      11.99
#
#             Order Date                         Purchase Address
# ...

# %%
df.shape
# Out:
# (195543, 6)

# %%
df.isnull().sum()
# Out:
# Order ID            567
# Product             567
# Quantity Ordered    567
# Price Each          567
# Order Date          567
# Purchase Address    567
# dtype: int64

# %%
df=df.dropna()

# %%
df.shape
# Out:
# (194976, 6)

# %%
df.duplicated().sum()
# Out:
# 20900

# %%
df= df.drop_duplicates()

# %%
df.shape
# Out:
# (174076, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 174076 entries, 0 to 175163
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          174076 non-null  object
#  1   Product           174076 non-null  object
#  2   Quantity Ordered  174076 non-null  object
#  3   Price Each        174076 non-null  object
#  4   Order Date        174076 non-null  object
#  5   Purchase Address  174076 non-null  object
# dtypes: object(6)
# memory usage: 9.3+ MB

# %%
df[df['Product'] == 'Product']
# Out:
#      Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 519  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#      Purchase Address
# 519  Purchase Address

# %%
df=df.drop(519)

# %%
duplicated_order=df[df.duplicated('Order ID',keep=False)]

# %%
duplicated_order
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 18       176574                Google Phone                1        600
# 19       176574        USB-C Charging Cable                1      11.95
# 32       176586      AAA Batteries (4-pack)                2       2.99
# ...         ...                         ...              ...        ...
# 175070   278706        USB-C Charging Cable                1      11.95
# 175074   278710        USB-C Charging Cable                1      11.95
# 175075   278710            27in FHD Monitor                1     149.99
# 175083   278718        USB-C Charging Cable                1      11.95
# 175084   278718  Bose SoundSport Headphones                1      99.99
#
#             Order Date                        Purchase Address
# ...

# %%
df['Product'].value_counts()
# Out:
# USB-C Charging Cable          20408
# Lightning Charging Cable      20285
# AAA Batteries (4-pack)        19329
# AA Batteries (4-pack)         19242
# Wired Headphones              17675
# Apple Airpods Headphones      14565
# Bose SoundSport Headphones    12472
# 27in FHD Monitor               7021
# iPhone                         6443
# 27in 4K Gaming Monitor         5844
# 34in Ultrawide Monitor         5798
# Google Phone                   5180
# Flatscreen TV                  4503
# Macbook Pro Laptop             4434
# ThinkPad Laptop                3877
# 20in Monitor                   3824
# Vareebadd Phone                1939
# LG Washing Machine              620
# LG Dryer                        616
# Name: Product, dtype: int64

# %%
df.loc[df['Order ID']== '141234']
# Out:
#       Order ID Product Quantity Ordered Price Each      Order Date  \
# 67547   141234  iPhone                1        700  01/22/19 21:25
#
#                       Purchase Address
# 67547  944 Walnut St, Boston, MA 02215

# %%
df2 = pd.crosstab(df['Order ID'], df['Product'])
df2.head()
# Out:
# Product   20in Monitor  27in 4K Gaming Monitor  27in FHD Monitor  \
# Order ID
# 141234               0                       0                 0
# 141235               0                       0                 0
# 141236               0                       0                 0
# 141237               0                       0                 1
# 141238               0                       0                 0
#
# Product   34in Ultrawide Monitor  AA Batteries (4-pack)  \
# Order ID
# 141234                         0                      0
# 141235                         0                      0
# 141236                         0                      0
# 141237                         0                      0
# 141238                         0                      0
#
# Product   AAA Batteries (4-pack)  Apple Airpods Headphones  \
# Order ID
# 141234                         0                         0
# 141235                         0                         0
# ...

# %%
df2.shape
# Out:
# (167230, 19)

# %%
df.shape
# Out:
# (174075, 6)

# %%
def encode(item_freq):
    res = 0
    if item_freq > 0:
        res = 1
    return res
    
basket_input = df2.applymap(encode)

# %%
basket_input
# Out:
# Product   20in Monitor  27in 4K Gaming Monitor  27in FHD Monitor  \
# Order ID
# 141234               0                       0                 0
# 141235               0                       0                 0
# 141236               0                       0                 0
# 141237               0                       0                 1
# 141238               0                       0                 0
# ...                ...                     ...               ...
# 319666               0                       0                 0
# 319667               0                       0                 0
# 319668               0                       0                 0
# 319669               0                       0                 0
# 319670               0                       0                 0
#
# Product   34in Ultrawide Monitor  AA Batteries (4-pack)  \
# Order ID
# 141234                         0                      0
# ...

# %%
from mlxtend.frequent_patterns import apriori

itemsets = apriori(basket_input, min_support=0.001, use_colnames=True)
# Out:
# C:\Users\stuti\AppData\Roaming\Python\Python39\site-packages\mlxtend\frequent_patterns\fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
itemsets
# Out:
#      support                                    itemsets
# 0   0.022867                              (20in Monitor)
# 1   0.034946                    (27in 4K Gaming Monitor)
# 2   0.041984                          (27in FHD Monitor)
# 3   0.034671                    (34in Ultrawide Monitor)
# 4   0.114967                     (AA Batteries (4-pack))
# 5   0.115470                    (AAA Batteries (4-pack))
# 6   0.087096                  (Apple Airpods Headphones)
# 7   0.074580                (Bose SoundSport Headphones)
# 8   0.026927                             (Flatscreen TV)
# 9   0.030975                              (Google Phone)
# 10  0.003684                                  (LG Dryer)
# 11  0.003707                        (LG Washing Machine)
# 12  0.121264                  (Lightning Charging Cable)
# 13  0.026514                        (Macbook Pro Laptop)
# 14  0.023184                           (ThinkPad Laptop)
# ...

# %%
from mlxtend.frequent_patterns import association_rules
rules = association_rules(itemsets, metric="lift", min_threshold=1)

# %%
rules
# Out:
#                   antecedents                 consequents  antecedent support  \
# 0              (Google Phone)      (USB-C Charging Cable)            0.030975
# 1      (USB-C Charging Cable)              (Google Phone)            0.122012
# 2  (Lightning Charging Cable)                    (iPhone)            0.121264
# 3                    (iPhone)  (Lightning Charging Cable)            0.038528
# 4      (USB-C Charging Cable)           (Vareebadd Phone)            0.122012
# 5           (Vareebadd Phone)      (USB-C Charging Cable)            0.011595
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.122012  0.005597    0.180695  1.480966  0.001818    1.071626
# 1            0.030975  0.005597    0.045873  1.480966  0.001818    1.015614
# 2            0.038528  0.005687    0.046896  1.217195  0.001015    1.008780
# 3            0.121264  0.005687    0.147602  1.217195  0.001015    1.030899
# ...

# %%
from mlxtend.frequent_patterns import apriori

itemsets = apriori(basket_input, min_support=0.001, use_colnames=True)
# Out:
# C:\Users\stuti\AppData\Roaming\Python\Python39\site-packages\mlxtend\frequent_patterns\fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
itemsets
# Out:
#      support                                    itemsets
# 0   0.022867                              (20in Monitor)
# 1   0.034946                    (27in 4K Gaming Monitor)
# 2   0.041984                          (27in FHD Monitor)
# 3   0.034671                    (34in Ultrawide Monitor)
# 4   0.114967                     (AA Batteries (4-pack))
# 5   0.115470                    (AAA Batteries (4-pack))
# 6   0.087096                  (Apple Airpods Headphones)
# 7   0.074580                (Bose SoundSport Headphones)
# 8   0.026927                             (Flatscreen TV)
# 9   0.030975                              (Google Phone)
# 10  0.003684                                  (LG Dryer)
# 11  0.003707                        (LG Washing Machine)
# 12  0.121264                  (Lightning Charging Cable)
# 13  0.026514                        (Macbook Pro Laptop)
# 14  0.023184                           (ThinkPad Laptop)
# ...

# %%
from mlxtend.frequent_patterns import association_rules
rules = association_rules(itemsets, metric="lift", min_threshold=0.1)

# %%
rules
# Out:
#                      antecedents                   consequents  \
# 0                       (iPhone)    (Apple Airpods Headphones)
# 1     (Apple Airpods Headphones)                      (iPhone)
# 2                 (Google Phone)  (Bose SoundSport Headphones)
# 3   (Bose SoundSport Headphones)                (Google Phone)
# 4                 (Google Phone)        (USB-C Charging Cable)
# 5         (USB-C Charging Cable)                (Google Phone)
# 6                 (Google Phone)            (Wired Headphones)
# 7             (Wired Headphones)                (Google Phone)
# 8     (Lightning Charging Cable)                      (iPhone)
# 9                       (iPhone)    (Lightning Charging Cable)
# 10        (USB-C Charging Cable)             (Vareebadd Phone)
# 11             (Vareebadd Phone)        (USB-C Charging Cable)
# 12            (Wired Headphones)                      (iPhone)
# 13                      (iPhone)            (Wired Headphones)
#
# ...

# %%
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 175159   278792       AA Batteries (4-pack)                1       3.84
# 175160   278793            Wired Headphones                1      11.99
# 175161   278794       AA Batteries (4-pack)                1       3.84
# 175162   278795                      iPhone                1        700
# 175163   278796            Wired Headphones                1      11.99
#
#             Order Date                         Purchase Address
# ...

# %%
grouped = df.groupby('Order ID')['Product'].apply(list).reset_index()

expanded = pd.DataFrame(grouped['Product'].to_list(), index=grouped['Order ID'])

final_df = expanded.reset_index()

# %%
final_df = final_df.drop('Order ID', axis =1)

# %%
final_df
# Out:
#                                  0     1     2     3     4
# 0                           iPhone  None  None  None  None
# 1         Lightning Charging Cable  None  None  None  None
# 2                 Wired Headphones  None  None  None  None
# 3                 27in FHD Monitor  None  None  None  None
# 4                 Wired Headphones  None  None  None  None
# ...                            ...   ...   ...   ...   ...
# 167225    Lightning Charging Cable  None  None  None  None
# 167226       AA Batteries (4-pack)  None  None  None  None
# 167227             Vareebadd Phone  None  None  None  None
# 167228            Wired Headphones  None  None  None  None
# 167229  Bose SoundSport Headphones  None  None  None  None
#
# [167230 rows x 5 columns]

# %%
from pyECLAT import ECLAT
eclat_instance = ECLAT(data=final_df, verbose=True)
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 457.66it/s]

# %%
eclat_instance.df_bin  
eclat_instance.uniq_
# Out:
# ['Lightning Charging Cable',
#  'AA Batteries (4-pack)',
#  'Bose SoundSport Headphones',
#  '34in Ultrawide Monitor',
#  'Macbook Pro Laptop',
#  '20in Monitor',
#  'AAA Batteries (4-pack)',
#  'iPhone',
#  'LG Washing Machine',
#  '27in FHD Monitor',
#  'Vareebadd Phone',
#  None,
#  'LG Dryer',
#  'Apple Airpods Headphones',
#  'Flatscreen TV',
#  'Google Phone',
#  '27in 4K Gaming Monitor',
#  'Wired Headphones',
#  'ThinkPad Laptop',
#  'USB-C Charging Cable']

# %%
get_ECLAT_indexes, get_ECLAT_supports = eclat_instance.fit(min_support=0.08,
                                                           min_combination=1,
                                                           max_combination=3,
                                                           separator=' & ',
                                                           verbose=True)
# Out:
# Combination 1 by 1
# 6it [00:00, 36.20it/s]
# Combination 2 by 2
# 15it [00:00, 130.15it/s]
# Combination 3 by 3
# 20it [00:00, 123.20it/s]

# %%
import pandas as pd
result = pd.DataFrame(get_ECLAT_supports.items(),columns=['Item', 'Support'])
result.sort_values(by=['Support'], ascending=False)
# Out:
#                        Item   Support
# 5      USB-C Charging Cable  0.122012
# 0  Lightning Charging Cable  0.121264
# 2    AAA Batteries (4-pack)  0.115470
# 1     AA Batteries (4-pack)  0.114967
# 4          Wired Headphones  0.105687
# 3  Apple Airpods Headphones  0.087096

# %%
result
# Out:
#                        Item   Support
# 0  Lightning Charging Cable  0.121264
# 1     AA Batteries (4-pack)  0.114967
# 2    AAA Batteries (4-pack)  0.115470
# 3  Apple Airpods Headphones  0.087096
# 4          Wired Headphones  0.105687
# 5      USB-C Charging Cable  0.122012
